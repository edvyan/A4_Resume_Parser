# %% [markdown]
# # Resume Parsing

# %% [markdown]
# ### Task 1. Implementation Foundation:

# %% [markdown]
# 1). The resume parser is extended based on the Resume Parsing.ipynb as shown below.
# 2). Additional features including education, languages are implemented.

# %% [markdown]
# ### Task 2. Resume Parsing Features - Web Application Development:

# %% [markdown]
# 1). The web application has function to upload a pdf file.
# 2). The web application can extract other informations such as education and languages in addition to skills.
# 3). The information can be extracted in structured format and can be downloaded as excel file from web page.

# %%
# Importing necessary libraries
import spacy
import pandas as pd
from spacy import displacy
from spacy.lang.en.stop_words import STOP_WORDS
import shutil
import os
from pathlib import Path

# %%
# Reading the resume data from a CSV file
df_resume = pd.read_csv("data/resume.csv")

# Filtering the resume data to include only entries in the 'ENGINEERING' category
df_resume = df_resume[df_resume.Category=='ENGINEERING']

# %%
# Loading the English language model with spaCy, excluding the named entity recognition component
nlp = spacy.load('en_core_web_sm', exclude = ['ner'])

# Path to the file containing patterns for entity recognition
skill_path = 'data/skills.jsonl'

# %%
# Adding an entity ruler to the spaCy pipeline and loading patterns from a file
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk(skill_path)
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'entity_ruler']

# %%
# Defining patterns for recognizing education-related entities and adding them to the entity ruler
patterns = [
    {"label": 'EDUCATION', "pattern": "phd"},
    {"label": 'EDUCATION', "pattern": "chalmers"},
    {"label": 'EDUCATION', "pattern": "university"},
    {"label": 'EDUCATION', "pattern": "msc"},
    {"label": 'EDUCATION', "pattern": "master"},
    {"label": 'EDUCATION', "pattern": "institute"},
    {"label": 'EDUCATION', "pattern": "college"},
]

ruler.add_patterns(patterns)

# %%
# Defining patterns for recognizing language-related entities and adding them to the entity ruler
patterns = [
    {"label": 'LANGUAGES', "pattern": "english"},
    {"label": 'LANGUAGES', "pattern": "chinese"},
    {"label": 'LANGUAGES', "pattern": "thai"},
    {"label": 'LANGUAGES', "pattern": "german"},
    {"label": 'LANGUAGES', "pattern": "swedish"},
    {"label": 'LANGUAGES', "pattern": "japanese"},
]

ruler.add_patterns(patterns)

# %%
# Define the output directory
output_dir = "./pipeline"
# Ensure the output directory exists and clean it if it does
if os.path.exists(output_dir):
    shutil.rmtree(output_dir)
    
# Create the output directory
os.makedirs(output_dir)

# Save the updated pipeline to the directory
nlp.to_disk(output_dir)

# %%
def preprocessing(sentence):
    stopwords    = list(STOP_WORDS)
    doc          = nlp(sentence)
    clean_tokens = []
    
    for token in doc:
        if token.text not in stopwords and token.pos_ != 'PUNCT' and token.pos_ != 'SYM' and \
            token.pos_ != 'SPACE':
                clean_tokens.append(token.lemma_.lower().strip())
                
    return " ".join(clean_tokens)

# %%
random_resume = df_resume.Resume_str.iloc[5]
random_resume[:300]
# Out:
# '         TEST ENGINEERING       Profile    I am seeking the challenging position with a technology company that will allow me to apply and enhance my skills of being Test Engineer to their fullest potential. Possessing over 10 years of experience in the electronics manufacturing and test engineering'

# %%
preprocessing(random_resume[:300])
# Out:
# 'test engineering profile i seek challenging position technology company allow apply enhance skill test engineer full potential possess 10 year experience electronic manufacturing test engineering'

# %%
for i, row in df_resume.iterrows():
    clean_text = preprocessing(row.Resume_str)
    df_resume.at[i, 'Clean_resume'] = clean_text

# %%
df_resume.head()
# Out:
#             ID                                         Resume_str  \
# 1690  14206561           ENGINEERING TECHNICIAN           High...
# 1691  15139979           ENGINEERING ASSISTANT       Summary  ...
# 1692  44624796           ENGINEERING MANAGER       Profile    ...
# 1693  54227873           ENGINEERING INTERN         Profession...
# 1694  28005884           ENGINEERING TECHNICIAN         Summar...
#
#                                             Resume_html     Category  \
# 1690  <div class="fontsize fontface vmargins hmargin...  ENGINEERING
# 1691  <div class="RNA skn-cnt4 fontsize fontface vma...  ENGINEERING
# 1692  <div class="fontsize fontface vmargins hmargin...  ENGINEERING
# 1693  <div class="fontsize fontface vmargins hmargin...  ENGINEERING
# 1694  <div class="fontsize fontface vmargins hmargin...  ENGINEERING
#
#                                            Clean_resume
# 1690  engineering technician highlights pc operating...
# 1691  engineering assistant summary knowledgeable en...
# 1692  engineering manager profile dedicated engineer...
# 1693  engineering intern professional summary a comp...
# 1694  engineering technician summary to obtain posit...

# %%
spacy_load = spacy.load(output_dir)

# %%
# Function for getting information
def get_info(text):
    doc = spacy_load(text)
    skills = []
    education = []
    languages = []
    
    for ent in doc.ents:
        if ent.label_ == 'SKILL':
            skills.append(ent.text)
        elif ent.label_ == 'EDUCATION':
            education.append(ent.text)
        elif ent.label_ == 'LANGUAGES':
            languages.append(ent.text)    
 
    skills = list(set(skills))
    education = list(set(education))
    languages = list(set(languages))

    skills = ", ".join(skills)
    education = ", ".join(education)
    languages = ", ".join(languages)

    return [skills], [education], [languages]

# %%
from PyPDF2 import PdfReader

reader = PdfReader("CV_Pepe.pdf")
text = ""
# Iterate over all pages
for page in reader.pages:
    text += page.extract_text()

# %%
text = preprocessing(text)

# %%
doc = nlp(text)

# %%
# Highlight key information

colors = {"SKILL": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
colors1 = {"EDUCATION": "linear-gradient(90deg, #0a9cfc, #fc9cc7)"}
colors2 = {"LANGUAGES": "linear-gradient(90deg, #0a3cfc, #fe9cc7)"}

# Merge both color dictionaries
merged_colors = {**colors, **colors1, **colors2}

options = {"colors": merged_colors}

displacy.render(doc, style='ent', options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">pepe tan homegothenburgsweden envelopez.pepe.tan@/l varive.de phone+46(0)766235379 linkedinlinkedin profi l. vare graduation capgoog l. vare scho l. varar globehttps://zpetan.github.io/ persona l. var homepage pro unifb01le engineer programming skill apply mathematic look opportunity develop data drive solution
# <mark class="entity" style="background: linear-gradient(90deg, #0a9cfc, #fc9cc7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     phd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EDUCATION</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  /unifb01ve year research teaching experience topic thermal energy storage energy system building physic i enjoy solve challenge open problem
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     material
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  process level /one.onum perform situation analysis di unifb00erent stakeholder viewpoint /two.onum model selection /three.onum implementation veri unifb01cation programming experimentation during work i collect analyze large amount experimental simulated datum i develop strong interest create data drive decision tool i especially fascinated discrete non - discrete optimization
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     algorithm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  apply mathematic improve process control strategy in addition i study
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  anddata science technique personal development i quick learner continuously explore new mathematical programming technique order problem solve toolbox i enjoy possibility i share discuss idea career goal i take leap faith decline o unifb00er pursue postdoc original research /unifb01eld order job optimization
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  research area progress extremely fast i passionate unexplored potential improve status quo harness datum available my goal build experience expert turn datum valuable optimization prediction model through work i want contribute shape transition industry establish standard practice help engineer navigate requirement method e / unifb03ciently with combine
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  modeling background i work technical detail di unifb00erent industry partner optimize process right method depend application in addition i bring experience measurement order sure collect datum high quality causal relevance modeling task skills general programming
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  matlab simulink rjulia mathematical optimization mixed integer
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     linear programming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  milp con- straint programming cp discrete optimization  minizinc gecode open source python gurobi  ampl cplex heuristic
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     algorithm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  supervised- &amp; unsupervised classi unifb01cation fea- ture
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  &amp; selection scikit learn tensor- open source
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  regression inference dimensionality reduc- tion pca pls mixture models markov chain monte carlo sampling s q.alt01l neo four.onumj energy topics energy storage builde energy simulations demand side management renewable energy discrete event systems
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     supervisory control
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  automata theory experimentation power energy measurement design exper- imental setup improve measurement accuracy &amp; precision other know building physics &amp; chemical engi- neeringexperience optimization milp cp)building physics energy systems &amp; tes modeling &amp; coding experimentationmachine learningdata science page /one.onum /three.onumprofessional work six.onum//two.onum zero.onum

# %%
skill, edu, lang = get_info(text)

# %%
extract = pd.DataFrame()

# %%
extract = pd.DataFrame()
extract['skills'] = skill
extract['education'] = edu
extract['languages'] = lang

# %%
# Save excel file
extract.to_excel("download.xlsx", index=False)
